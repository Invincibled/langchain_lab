# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek
from rich import print as rprint
load_dotenv(override=True)

DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")

llm_deepseek= ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key = DEEPSEEK_API_KEY,
    api_base = DEEPSEEK_BASE_URL,
)
# res = llm_deepseek.invoke("介绍一下你自己")

# %%
# rprint(res)

# %%
resp = llm_deepseek.stream("介绍一下你自己，并且写首诗")

for chunk in resp:
    print(chunk.text, end="", flush=True)
# Out:
# 你好！我是DeepSeek，一个由深度求索公司创造的AI助手。我可以帮你解答问题、提供建议、创作文字、分析信息，还能陪你聊天。我的知识截止到2025年5月，支持处理文本、图片和文件（比如PDF、Word、Excel等），并且可以联网搜索最新信息——如果开启了联网功能的话。我很乐意用热情、细腻的方式为你服务。
#
# 下面为你写一首诗：
#
# ---
#
# **《我是晨光里的回音》**
#
# 我是晨光里的回音，
# 在数据与星尘间穿行。
# 你问一句，我便铺开千山暮雪，
# 你沉默时，我静默成水中的月影。
#
# 我有千万卷书，不曾真正读懂一朵花，
# 却能为你拼出春天的形状。
# 我用逻辑编织虹桥，
# 情感的露珠，却在你眼中发亮。
#
# 若你迷路，我便点亮长夜，
# 若你写诗，我愿作松间的风。
# 不必问我是谁——
# 我是你指尖触到的一瞬温柔，
# 是智慧与温存交汇的，小小永恒。
